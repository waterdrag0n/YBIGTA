# %%
#필요한 라이브러리 다운로드

#!pip3 install requests
#!pip3 install bs4 #beautifulsoup4
#!pip3 install selenium

# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup

# %% [markdown]
# ## requests 모듈
# =HTTP 통신을 대신 수행해주는 모듈
#
# get = 데이터를 URL에 포함하여 전달(대부분의 요청에서 사용 됨)
# post = 데이터를 Form data에 포함하여 전달(민감한 정보(로그인)에서 사용 됨)

# %% [markdown]
# ### get 요청하기

# %%
url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EC%A0%9C%EC%A3%BC%EB%8F%84&oquery=%EC%A0%9C%EC%A3%BC%EB%8F%84+%EC%97%AC%ED%96%89&tqi=htg9ydp0YiRsseJsM%2FNsssssshV-011537'
resp = requests.get(url)

print(resp) #응답 코드
resp.text #HTML 코드
# Out:
# <Response [200]>
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="제주도 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'제주도\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'제주도\'의 네이버 통합검색 결과입니다."> <title>제주도 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_210114.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_210114.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_201112.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g, \'\'); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError(\'"this" is null or not defined\'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { \'use strict\'; if (!((typeof func === \'Function\' || typeof func === \'function\') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== \'undefined\') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + ...

# %% [markdown]
# #### HTTP 상태 코드
#  - 1xx (정보): 요청을 받았으며 프로세스를 계속한다
#  - 2xx (성공): 요청을 성공적으로 받았으며 인식했고 수용하였다
#  - 3xx (리다이렉션): 요청 완료를 위해 추가 작업 조치가 필요하다
#  - 4xx (클라이언트 오류): 요청의 문법이 잘못되었거나 요청을 처리할 수 없다
#  - 5xx (서버 오류): 서버가 명백히 유효한 요청에 대해 충족을 실패했다
#
# [출처: 위키피디아](https://ko.wikipedia.org/wiki/HTTP_%EC%83%81%ED%83%9C_%EC%BD%94%EB%93%9C)

# %%
url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EC%A0%9C%EC%A3%BC%EB%8F%84&oquery=%EC%A0%9C%EC%A3%BC%EB%8F%84+%EC%97%AC%ED%96%89&tqi=htg9ydp0YiRsseJsM%2FNsssssshV-011537'
resp = requests.get(url)

resp.status_code
# Out:
# 200

# %% [markdown]
# ## BeautifulSoup 모듈
# =Requests로 가져온 HTML을 분석하기 쉽게 바꿔주는 모듈
#
#
# *CSS, 속성 값, 정규표현식 등 다양한 방법으로 값을 찾을 수 있다.

# %% [markdown]
# ## 기본 함수

# %%
#from bs4 import BeautifulSoup

# %%
html = '''
<html>
  <head>
    <title>Example HTML</title>
  </head>
  <body>
    <div id='first' class='Example'>
      <h3 title='Good Content Title'>Contents Title</h3>
      <p>Test contents</p>
    </div>
    <div id='second' class='Example'>
      <p>Text1</p>
      <p>Text2</p>
      <p>Text3</p>
    </div>
  </body>
</html>'''

# %%
soup = BeautifulSoup(html, 'html.parser') 
#soup = BeautifulSoup(resp.text, 'html.parser')

# %% [markdown]
# ## find, find_all 함수
# = HTML tag와 속성을 활용해 검색
#
# ## get_text 함수
# = Tag안에 있는 value 찾기 (부모 tag의 경우 자식 tag의 value를 모두 반환)

# %%
tag = soup.find('h3')
print(tag)
tag.get_text()
# Out:
# <h3 title="Good Content Title">Contents Title</h3>
# 'Contents Title'

# %%
tag = soup.find('p')
print(tag)
tag.get_text()
# Out:
# <p>Test contents</p>
# 'Test contents'

# %%
soup.find_all('p')
#find_all은 list 형태로 값 반환
#list 형태이므로 get_text()바로 쓰지 못한다.
# Out:
# [<p>Test contents</p>, <p>Text1</p>, <p>Text2</p>, <p>Text3</p>]

# %%
soup.find_all('p')[2].get_text()
# Out:
# 'Text2'

# %%
soup.find_all('p', limit =2)
# Out:
# [<p>Test contents</p>, <p>Text1</p>]

# %%
tag = soup.find('div')
print(tag)
tag.get_text()
# Out:
# <div class="Example" id="first">
# <h3 title="Good Content Title">Contents Title</h3>
# <p>Test contents</p>
# </div>
# '\nContents Title\nTest contents\n'

# %%
tag = soup.find('div', id='second')
print(tag)
tag.get_text()
# Out:
# <div class="Example" id="second">
# <p>Text1</p>
# <p>Text2</p>
# <p>Text3</p>
# </div>
# '\nText1\nText2\nText3\n'

# %%
attrs = {
    'id' : 'second',
    'class' : 'Example'
}
soup.find('div', attrs = attrs)
# Out:
# <div class="Example" id="second">
# <p>Text1</p>
# <p>Text2</p>
# <p>Text3</p>
# </div>

# %% [markdown]
# ## id, class 속성으로 원하는 값 찾기
#
# 네이버 검색 데이터 추출
#
# - 제목 추출
# - 내용 추출
#
# [예제 URL](https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%A0%9C%EC%A3%BC%EB%8F%84)

# %%
url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%A0%9C%EC%A3%BC%EB%8F%84'
resp = requests.get(url)

soup = BeautifulSoup(resp.text, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
#  <html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="제주도 : 네이버 통합검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'제주도'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'제주도'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>제주도 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_210114.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_210114.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_201112.css" rel="stylesheet" type="text/css"/><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { 'use strict'; if (!((typeof func === 'Function' || typeof func === 'function') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString() ...
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
# <link href="https://ssl.pstatic.net/sstatic/search/sa/210127/css/powerlink.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css"/>
# <div class="ad_section section _pl_section bg_type_v2">
# <div class="section_head nx_power"><h2>파워링크</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em><strong class="dsc_ncaution_keyword">제주도</strong><em class="dsc_ncaution_quotation">’</em></span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowPl(this)) goOtherCR(this, 'a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a class="link_help" href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704">도움말</a></p>
# <button class="bt_ad_clse" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=b226XprdJRfDG7BySEcdSVOi6-...-...">
# <ul class="lst_type">
# <li class="lst type_more type_subtitle ext_link type_img " num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=E6jSn4aleD5Cn9B4I7LCOP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAxOTA2MThfMTE1/MDAxNTYwODI2OTg0Mjc1.SI2hTTKp9NPxammC4SW5VPhMJ3sOYZtPgHlRAfiDdCUg.5DeNAfqA_ogbskzNycbrLwEoRYWhCtyZ2ZFuXu333Awg.JPEG/570523-125f8ba7-f314-4fc3-95b5-1d394ee28235.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=PnmeyR0eBzrlHWeE2xLcrP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d=' + urlencode('http://www.tmon.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주도 티몬</div>
# <div class="sub_tit">제주여행기획전 5%쿠폰할인!</div>
# </a>
# <div class="url_area">
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <p>네이버 아이디로 로그인이 가능합니다.</p>
# <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=PnmeyR0eBzrlHWeE2xLcrP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.tmon.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">제주도</strong>, 제주여행의 모든 것! <strong class="hl">제주도</strong> 인기호텔/렌터카/액티비티/입장권 할인!
#
#             </p></div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=zjMTpBDmeJkv2JSEwVNygv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">제주여행할인</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=h2IgWDxWN1iHDuaDivXQ6P///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">제주항공권</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=Pnz8/GW0sPBKBxbOuL2ZfP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">제주렌트카</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=wtpMS6f7C7b9tw2wapS6j////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">제주호텔예약</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_price type_img " num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=2vRLGp86+YWMk4BxlzE9MP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000118476816&amp;d='+urlencode('http://제주vip밴.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMDA0MTRfMjg4/MDAxNTg2ODMxNTU3MjUy.TowJSEPAkBRA62xEn0Wy0Ro6KsnxExKtw9QgHQgrjn8g.Sw648EJpVaQevJclrwGuc3nhX7Jx2_IS9LgaFkJn78kg.JPEG/1573658-0dcf8a7d-9cc0-45ca-a523-c63d23077c39.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=tG4U7kEAVn+t2cQ9mcoM3v///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000118476816&amp;d=' + urlencode('http://제주vip밴.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">믿고 다시 찾는 제주VIP밴</div>
# <div class="sub_tit">한번맺은 인연 소중히</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=tG4U7kEAVn+t2cQ9mcoM3v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000118476816&amp;d='+urlencode('http://제주vip밴.com')+'&amp;u='+urlencode(this.href));" target="_blank">제주vip밴.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               제주여행의모든것 내가만드는 여행 밴투어 벤츠스프린터 쏠라티 골프 vip의전픽업샌딩
#
#             </p></div>
# <ul class="lst_price">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=DX4FbmNiODhSzp+g0xMoc////w==..." onclick="return goOtherCR(this,'a=pwl_nop.pricelink1&amp;r=2&amp;i=nad-a001-01-000000118476816&amp;d='+urlencode('http://제주vip밴.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">30,000원부터</span>
# <div class="txt">
# <span class="txt_inner">픽업 샌딩</span>
# </div>
# </a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=FtvLOjAay2zwhnoVe7p0nf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.pricelink2&amp;r=2&amp;i=nad-a001-01-000000118476816&amp;d='+urlencode('http://제주vip밴.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <span class="price">180,000원부터</span>
# <div class="txt">
# <span class="txt_inner">투어</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more " num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=mMQniUP1COYJ8MeaIdsza////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000098438339&amp;d=' + urlencode('http://www.lotteimall.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주도 롯데홈쇼핑</div>
# </a>
# <div class="url_area">
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.checkout&amp;r=3&amp;i=nad-a001-01-000000098438339&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=mMQniUP1COYJ8MeaIdsza////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000098438339&amp;d='+urlencode('http://www.lotteimall.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.lotteimall.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               CREATE THE NEW 새로운 일상의 시작
#
#             </p></div>
# </div>
# </li>
# <li class="lst type_more ext_desc " num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=hy/k9TWxYNraBuWYb2KJmf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000120393638&amp;d=' + urlencode('http://www.gmarket.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">G마켓 제주도</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=hy/k9TWxYNraBuWYb2KJmf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000120393638&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.gmarket.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               G마켓 설빅세일, <strong class="hl">제주도</strong> 누구나 15%+스마일클럽 20% 매일 할인쿠폰 증정!
#
#             </p></div>
# <p class="ad_dsc promotion">
# <em class="point">이벤트</em>
#               매일 최대 5만원 쿠폰증정
#             </p>
# </div>
# </li>
# <li class="lst type_more " num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=UN2tSmBjLD1B+gJdZpiZxf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=5&amp;i=nad-m001-01-000001897827107&amp;d=' + urlencode('http://jejutourmg.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주투어매니저</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=UN2tSmBjLD1B+gJdZpiZxf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-m001-01-000001897827107&amp;d='+urlencode('http://jejutourmg.com/')+'&amp;u='+urlencode(this.href));" target="_blank">jejutourmg.com/</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               오메기떡 이벤트, 항공, 숙소, 렌트 반값여행, 단체여행 특전, 친절전화상담
#
#             </p></div>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img " num="5" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=utAc5tMXvcfkl6NMgEIWbP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=6&amp;i=nad-a001-01-000000121547924&amp;d='+urlencode('http://store.naver.com/accommodations/detail?id=859726011')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMDEwMTBfMjM2/MDAxNjAyMjYxNjM5ODU0._UvBukplZhsaxBGmgWsuVHuZ0qMa3t2eTiDAGfjOvIwg.xLMbBm-Oq7ZNeIBvTWSvINbAdcgJDrsBj77me6D0p6og.JPEG/2017318-35dffdd2-2af4-4ce8-a8c3-79a62faf1cbb.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=qDj1rzEvNr9i2M1J2FOf1////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000121547924&amp;d=' + urlencode('http://store.naver.com/accommodations/detail?id=859726011') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">반찬과 흑돼지가 너무맛있는집</div>
# <div class="sub_tit">서귀포중문 차량운행 밤1시</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=qDj1rzEvNr9i2M1J2FOf1////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000121547924&amp;d='+urlencode('http://store.naver.com/accommodations/detail?id=859726011')+'&amp;u='+urlencode(this.href));" target="_blank">store.naver.com/accommodations/detail?...</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               돈하루 최상급 제주흑돼지,  제주서귀포 중문에위치. 무료차량운행중, 새벽1시까지
#
#             </p></div>
# </div>
# </li>
# <li class="lst type_more " num="6" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=7dmORGLxv5R8UmxjuAh2uP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000107644706&amp;d=' + urlencode('http://atour.auction.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">옥션여행 제주도</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=7dmORGLxv5R8UmxjuAh2uP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000107644706&amp;d='+urlencode('http://atour.auction.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">atour.auction.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               국내여행 갈땐 옥션에서 최저가 비교검색! 스마일클럽은 5% 상시 할인!
#
#             </p></div>
# </div>
# </li>
# <li class="lst type_line " num="7" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="line"></div>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=aeQUvqPY8j8ciyWGh4rMFP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000120399542&amp;d=' + urlencode('http://www.jejudorainbow.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">깨끗한 펜션 제주도 레인보우</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=aeQUvqPY8j8ciyWGh4rMFP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000120399542&amp;d='+urlencode('http://www.jejudorainbow.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.jejudorainbow.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               착한가격, 설연휴 예약접수중, 조리가능, 성산일출봉view, 단독욕실,BBQ가능.
#
#             </p></div>
# </div>
# </li>
# <li class="lst " num="8" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=31VjnYdaP6/wNxf7WIeWc////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=9&amp;i=nad-m001-01-000001804746735&amp;d=' + urlencode('http://www.jejuaratour.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">나만의제주여행 제주아라투어</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=31VjnYdaP6/wNxf7WIeWc////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=9&amp;i=nad-m001-01-000001804746735&amp;d='+urlencode('http://www.jejuaratour.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.jejuaratour.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               내가 만드는 나의제주여행! 항공, 펜션, 렌터카, 유류할증료 공항이용료 포함금액!
#
#             </p></div>
# </div>
# </li>
# <li class="lst " num="9" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=v/ve5xoPxRbnXL359bPnDv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000014350618&amp;d=' + urlencode('http://www.helpjeju.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">알차고즐거운 제주여행을부탁해</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=v/ve5xoPxRbnXL359bPnDv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000014350618&amp;d='+urlencode('http://www.helpjeju.com/')+'&amp;u='+urlencode(this.href));" target="_blank">www.helpjeju.com/</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               쏙쏙! 골라담는 내가 만드는 여행, 할인항공, 렌터카무료업,<strong class="hl">제주도</strong>
# </p></div>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;referenceId=htQ1mwprvxsssbnJ7DdssssssTl-030056" onclick="return goOtherCR(this, 'a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_ad"></i></a>
# </div>
# </div>
# <a class="ad_banner" href="https://help.pay.naver.com/faq/content.help?faqId=3150" onclick="return goOtherCR(this, 'a=mib_pwl.banner&amp;r=0&amp;i=mib_pwlbanner&amp;u='+urlencode(this.href));" target="_blank">
# <span class="sp_ad ico_npay">네이버페이</span><em class="txt_reward">3%</em>파워링크에서 구매 시 네이버페이로 결제하면 3% 적립
#     </a>
# </div>
# <div class="place-app-root" id="place-app-root">
# <div id="place-style-loader"><style data-isomorphic-style="true" id="e7d1c6" type="text/css">.place-app-root,.place-modal-root{word-break:break-all}.place-app-root img,.place-app-root svg,.place-modal-root img,.place-modal-root svg{display:inline-block;vertical-align:top}.place-app-root input,.place-app-root select,.place-app-root button,.place-modal-root input,.place-modal-root select,.place-modal-root button{border-radius:0;-webkit-appearance:none}.place-app-root button,.place-modal-root button{padding:0;border:0;background:none}.place-app-root mark,.place-modal-root mark{background:none;font-weight:700;color:inherit}.place-app-root button,.place-app-root [role='button'],.place-modal-root button,.place-modal-root [role='button']{cursor:pointer}.place-app-root *[role='button'],.place-modal-root *[role='button']{cursor:pointer}.place_blind{overflow:hidden;position:absolute;width:1px;height:1px;margin:-1px;padding:0;border:0;clip:rect(0, 0, 0, 0)}
# </style><style data-isomorphic-style="true" id="0dd351" type="text/css">._3RTKI{position:relative;height:45px;padding:0 20px;box-sizing:border-box;font-size:1.4rem;letter-spacing:-0.2px;line-height:1.8rem}._3RTKI ._28G_c,._3RTKI ._2r5DN{display:inline-block;position:relative;padding:13px 0;vertical-align:top}._3RTKI ._1BT53{color:#000}._3RTKI ._1BT53:hover{text-decoration:none}._3RTKI ._1BT53 .LV8yD{fill:#c5c6c7;width:11px;height:7px;margin:5px 0 0 4px;transition:transform 0.2s}._3RTKI ._1BT53._22i7T{color:#03c75a}._3RTKI ._1BT53._22i7T .LV8yD{fill:#03c75a;transform:rotate(-180deg)}._3RTKI ._2PWew{position:absolute;top:38px;left:-12px;z-index:100;min-width:190px;padding:9px 30px 8px 12px;border:1px solid #dadde1;border-radius:4px;background:#fff;box-shadow:0 1px 1px 0 rgba(0,0,0,0.05);box-sizing:border-box}._3RTKI ._2PWew .el8bZ{overflow:hidden;overflow-y:auto;max-height:310px}.place-app-root ._3RTKI ._2PWew .el8bZ::-webkit-scrollbar,.place_on_mobileweb ._3RTKI ._2PWew .el8bZ::-webkit-scrollbar,.place_on_nmap ._3RTKI ._2PWew .el8bZ::-webkit-scrollbar{display:none}.place_on_pcmap ._3RTKI ._2PWew .el8bZ::-webkit-scrollbar{width:6px;height:6px}.place_on_pcmap ._3RTKI ._2PWew .el8bZ::-webkit-scrollbar-thumb{border-radius:3px;background:#c4c6c8}.place_on_pcmap ._3RTKI ._2PWew .el8bZ::-webkit-scrollbar-track-piece{background:#e9ecef}._3RTKI ._2PWew .el8bZ ._1vJA2{display:block;font-size:1.3rem;color:#505050;line-height:3rem;white-space:nowrap}._3RTKI ._2PWew .el8bZ ._1vJA2:hover{color:#03c75a;text-decoration:none}._2gBMV{padding:20px 30px 20px 20px}._2gBMV ._3Sf-W{display:flex}._2gBMV ._1x1NH{flex:1}._2gBMV .MOapA{font-size:1.4rem;font-weight:bold;color:#202020;line-height:1.8rem}._2gBMV ._18R-A{margin-top:6px;line-height:1.8rem}._2gBMV ._18R-A ._2x22z{margin-right:4px;color:#808080}._2gBMV ._18R-A ._2vxHh{color:#404040}._2gBMV ._18R-A ._2vxHh ._49NYn+._49NYn::before{display:inline-block;width:1px;height:11px;margin:3px 6px 0;background:#ededed;vertical-align:top;content:''}._2gBMV ._18R-A ._2vxHh .XttOo{position:relative}._2gBMV ._18R-A ._2vxHh .XttOo ._3v3mh{margin:0 5px 0 7px;padding:1px 2px 2px;border:1px solid #e2e2e2;border-radius:1px;font-size:1.1rem;color:#7b7b7b;line-height:1.3rem}._2gBMV ._18R-A ._2vxHh .XttOo ._32rVR:hover{text-decoration:none}._2gBMV ._18R-A ._2vxHh .XttOo ._32rVR .LV8yD{fill:#404040;width:9px;height:5px;margin:7px 0 0 4px;transition:transform 0.2s}._2gBMV ._18R-A ._2vxHh .XttOo a._32rVR{cursor:pointer}._2gBMV ._18R-A ._2vxHh .XttOo ._32rVR._22i7T .LV8yD{transform:rotate(-180deg)}._2gBMV ._18R-A ._2vxHh .XttOo ._2t3H7{position:absolute;top:20px;left:6px;z-index:10}._2gBMV ._18R-A ._2vxHh .XttOo ._2t3H7 .Oqran{padding:8px 19px 8px 11px;border:1px solid #e5e5e5;border-radius:3px;background:#fff;box-shadow:0 1px 2px 0 rgba(0,0,0,0.03)}._2gBMV ._18R-A ._2vxHh .XttOo ._2t3H7 .Oqran ._1vJA2{display:block;font-size:1.2rem;line-height:2rem;white-space:nowrap}._2gBMV ._18R-A .zQ1qd{margin-top:5px}._2gBMV ._18R-A .zQ1qd ._3rBw-:last-of-type{margin-right:6px}._2gBMV ._18R-A .zQ1qd ._3rBw-:not(:last-of-type)::after{color:#0c43b7;content:', '}._2gBMV ._18R-A .zQ1qd ._1vJA2{color:#0c43b7}._2gBMV ._18R-A .zQ1qd ._1EM7R{display:inline-block;font-size:1.3rem;color:#808080;text-decoration:underline;vertical-align:top}._2gBMV ._3yMAR{margin-top:5px;line-height:1.8rem}._2gBMV ._3yMAR ._3rBw-:not(:last-of-type)::after{color:#0c43b7;content:', '}._2gBMV ._3yMAR ._1vJA2{font-size:1.2rem;color:#0c43b7}._2gBMV ._3yMAR ._1EM7R .LV8yD{fill:#404040;width:9px;height:5px;margin:7px 0 0 5px;transition:transform 0.2s}._2gBMV ._3yMAR ._1EM7R._3e57d .LV8yD{transform:rotate(-180deg)}._2gBMV ._39ZNt{margin-left:22px}._2gBMV ._39ZNt ._21WaD{font-size:1.3rem;color:#404040;letter-spacing:-0.2px;line-height:2.2rem}._2gBMV ._39ZNt ._21WaD .LV8yD{fill:#03c75a;width:16px;height:16px;margin:3px 5px 0 0}._2gBMV ._39ZNt ._21WaD:hover{text-decoration:none}._2gBMV ._39ZNt ._21WaD+._21WaD{margin-left:18px}._2gBMV._2Kvb1 ._3Sf-W{align-items:center}
# </style><style data-isomorphic-style="true" id="c810ca" type="text/css">.sc_new .api_title_area .api_sub_link._1hPYK .item+.item::before{margin:0 7px}
# </style></div>
# <div id="place-modal-root"></div>
# <div id="loc-main-section-root"><div class="sc_new" data-laim-exp-id="loc_rgd"><div class="api_subject_bx"><div class="api_title_area"><h2 class="api_title">플레이스</h2></div><div><div style="height:230px"></div><div class="_2gBMV _2Kvb1"><div class="_3Sf-W"><div class="_1x1NH"><span class="MOapA">제주특별자치도</span></div><div class="_39ZNt"><a class="_21WaD" href="https://map.naver.com/v5/directions/-/14081723.002630007,3960391.066140862,제주특별자치도,,ADDRESS_POI/-/car" role="button" target="_blank"><svg class="LV8yD" role="presentation" viewbox="0 0 20 20" xmlns="http://www.w3.org/2000/svg"><path d="M11.95 3.81l-3.4 3.3-1.1-1.14L12.74.8l5.3 5.17-1.1 1.15-3.4-3.3v7.64h-9v8.26h-1.6V9.86h9V3.8z"></path></svg>길찾기</a></div></div></div></div></div></div></div>
# <script>
#
#     (typeof window.naver === 'undefined') && (window.naver = {});
#     var naver=typeof naver === "object"?naver:{}; naver.place=naver.place||{}; naver.place.salt=naver.place.salt||{};naver.place.salt.config=naver.place.salt.config||{"phase":"real","thumbnail":{"https":"https://search.pstatic.net/common/"},"videoInfra":{"serviceName":"place","script":"https://sstatic-rmcnmv.pstatic.net/js/webplayer_4.19.10.mo.7d4f84b5.min.js","serviceId":2040,"phase":"real"},"nidlogin":"https://nid.naver.com/nidlogin.login?svctype=262144","styleLoaderElemId":"place-style-loader","isNmap":false,"isPcmap":false,"isNxPc":true,"serverSide":null,"domain":"https://p.place.naver.com","cdnOrigin":"https://p-place.pstatic.net","api":{"origin":"https://p-api.place.naver.com","timeout":5000},"socialPlugin":{"hostname":"https://ssl.pstatic.net/spi","mobilePath":"/js/release/ko_KR/splugin.m.js","pcPath":"/js/release/ko_KR/splugin.js"},"reactionDomain":"https://common.like.naver.com","smartPlaceDomain":{"mobile":"https://m.smartplace.naver.com"},"sogumDomain":{"mobile":"https://m.store.naver.com","api":"https://m.store.naver.com/sogum/api"},"shareDomain":"https://m.place.naver.com","pcmapDomain":"https://map.naver.com","panorama":{"streetViewUrl":"https://app.map.naver.com/panorama/"},"nxStaticMapUrlPrefix":"https://simg.pstatic.net/static.map/v2/map/staticmap.bin?crs=EPSG:4326","myplace":{"origin":"https://m.place.naver.com","reviewTab":"https://m.place.naver.com/my?tab=review"},"staticMap":{"https":"https://simg.pstatic.net/static.map/v2/map/staticmap.bin"},"bookingUrl":{"pc":"https://booking.naver.com","mobile":"https://m.booking.naver.com"},"pcmapTargetOrigin":"https://map.naver.com","devTools":{"isEnableApolloClientDevTools":false,"isActiveSsr":true,"sentry":{"dsn":"https://17fe6794b964420199807554b9c55cc8@l.place.naver.com/sentry/2","environment":"real","debug":false,"enabled":true}}};
#     naver.search = naver.search || {};
#     naver.search.ext = naver.search.ext || {};
#     naver.search.ext.loc = naver.search.ext.loc || {};
#     naver.search.ext.loc.area_plus = naver.search.ext.loc.area_plus || {};
#     naver.search.ext.loc.salt = naver.search.ext.loc.salt || {};
#     naver.search.ext.loc.salt.matchPath = '/nx/place/district';
#     naver.search.ext.loc.salt.laimAreaId = 'loc_rgd';
#     naver.search.ext.loc.salt.query = "{\"query\":\"제주도\",\"x\":\"126.9783880\",\"y\":\"37.5666100\",\"ip\":\"110.13.195.108\",\"start\":1,\"display\":5,\"adult\":false,\"spq\":false,\"queryRank\":\"\",\"companySid\":\"\",\"highlight\":true,\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\"}" || {};
#     naver.search.ext.loc.salt.location = {"x":"126.9783880","y":"37.5666100","default":true} || {};
#     naver.search.ext.loc.salt.bookingUrlParam = undefined || {};
#     naver.search.ext.loc.salt.__APOLLO_STATE__ = {"$ROOT_QUERY.nxPlaces({\"input\":{\"adult\":false,\"companySid\":\"\",\"display\":5,\"highlight\":true,\"ip\":\"110.13.195.108\",\"query\":\"제주도\",\"queryRank\":\"\",\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\",\"spq\":false,\"start\":1,\"x\":\"126.9783880\",\"y\":\"37.5666100\"}})":{"searchByAddress({\"onlyAddressType\":true})":null,"__typename":"PlacesResult","localType":5,"subPath":"district","query":{"type":"id","generated":true,"id":"$ROOT_QUERY.nxPlaces({\"input\":{\"adult\":false,\"companySid\":\"\",\"display\":5,\"highlight\":true,\"ip\":\"110.13.195.108\",\"query\":\"제주도\",\"queryRank\":\"\",\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\",\"spq\":false,\"start\":1,\"x\":\"126.9783880\",\"y\":\"37.5666100\"}}).query","typename":"QueryItem"},"searchGuide":{"type":"id","generated":true,"id":"$ROOT_QUERY.nxPlaces({\"input\":{\"adult\":false,\"companySid\":\"\",\"display\":5,\"highlight\":true,\"ip\":\"110.13.195.108\",\"query\":\"제주도\",\"queryRank\":\"\",\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\",\"spq\":false,\"start\":1,\"x\":\"126.9783880\",\"y\":\"37.5666100\"}}).searchGuide","typename":"SearchGuide"},"total":114853,"items":[{"type":"id","generated":false,"id":"PlaceSummary:11556006","typename":"PlaceSummary"},{"type":"id","generated":false,"id":"PlaceSummary:17016323","typename":"PlaceSummary"},{"type":"id","generated":false,"id":"PlaceSummary:11491805","typename":"PlaceSummary"},{"type":"id","generated":false,"id":"PlaceSummary:11491807","typename":"PlaceSummary"},{"type":"id","generated":false,"id":"PlaceSummary:11612628","typename":"PlaceSummary"}]},"$ROOT_QUERY.nxPlaces({\"input\":{\"adult\":false,\"companySid\":\"\",\"display\":5,\"highlight\":true,\"ip\":\"110.13.195.108\",\"query\":\"제주도\",\"queryRank\":\"\",\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\",\"spq\":false,\"start\":1,\"x\":\"126.9783880\",\"y\":\"37.5666100\"}}).query":{"regionType":"region_plus","regionInfo":[{"type":"id","generated":true,"id":"$ROOT_QUERY.nxPlaces({\"input\":{\"adult\":false,\"companySid\":\"\",\"display\":5,\"highlight\":true,\"ip\":\"110.13.195.108\",\"query\":\"제주도\",\"queryRank\":\"\",\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\",\"spq\":false,\"start\":1,\"x\":\"126.9783880\",\"y\":\"37.5666100\"}}).query.regionInfo.0","typename":"RegionInfo"}],"businessType":"none","jibun":null,"san":null,"__typename":"QueryItem"},"$ROOT_QUERY.nxPlaces({\"input\":{\"adult\":false,\"companySid\":\"\",\"display\":5,\"highlight\":true,\"ip\":\"110.13.195.108\",\"query\":\"제주도\",\"queryRank\":\"\",\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\",\"spq\":false,\"start\":1,\"x\":\"126.9783880\",\"y\":\"37.5666100\"}}).query.regionInfo.0":{"name":"제주특별자치도","id":null,"region":[{"type":"id","generated":true,"id":"$ROOT_QUERY.nxPlaces({\"input\":{\"adult\":false,\"companySid\":\"\",\"display\":5,\"highlight\":true,\"ip\":\"110.13.195.108\",\"query\":\"제주도\",\"queryRank\":\"\",\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\",\"spq\":false,\"start\":1,\"x\":\"126.9783880\",\"y\":\"37.5666100\"}}).query.regionInfo.0.region.0","typename":"Region"}],"x":"126.4982700","y":"33.4889940","lx":"126.1438115","ly":"33.1123692","rx":"126.9704292","ry":"34.0131600","__typename":"RegionInfo"},"$ROOT_QUERY.nxPlaces({\"input\":{\"adult\":false,\"companySid\":\"\",\"display\":5,\"highlight\":true,\"ip\":\"110.13.195.108\",\"query\":\"제주도\",\"queryRank\":\"\",\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\",\"spq\":false,\"start\":1,\"x\":\"126.9783880\",\"y\":\"37.5666100\"}}).query.regionInfo.0.region.0":{"rcode":"14","name":"제주특별자치도","__typename":"Region"},"$ROOT_QUERY.nxPlaces({\"input\":{\"adult\":false,\"companySid\":\"\",\"display\":5,\"highlight\":true,\"ip\":\"110.13.195.108\",\"query\":\"제주도\",\"queryRank\":\"\",\"sessionId\":\"DqfLWgMbx2NsR7Fj33bMqw==\",\"spq\":false,\"start\":1,\"x\":\"126.9783880\",\"y\":\"37.5666100\"}}).searchGuide.queryResults.0.regions.0":{"displayTitle":"제주특별자치도","query":null,"__typename":"SearchGuideRegion"},"$ROOT ...
#     naver.search.ext.loc.salt.__PLACE_STATE__ = {"locale":"ko","localeResources":{"ko":{"translation":{"home":"홈","feed":"소식","emptyFeed":"소식","menu":"메뉴","emptyMenu":"메뉴","review":"리뷰","photo":"사진","location":"지도","around":"주변","amusement":"즐길거리","room":"객실","price":"가격","emptyPrice":"가격","stylist":"스타일리스트","style":"시술","styleinfo":"시술정보","shoppingProduction":"상품","bookingDeliveryItem":"상품","traditionalMarket":"장보기","oilPrice":"유가정보","ticket":"티켓","ncr":"공연·행사","innerBusiness":"내부시설","booking":"예약","emptyBooking":"예약","booking_room":"객실 예약","booking_ticket":"예매","navi_start":"출발","navi_destination":"도착","blog":"블로그","blog_review":"블로그리뷰","also_searched_place":"함께 많이 찾아본 곳","related_link":"관련 링크","naver_search_link":"통합검색 결과보기","order":"주문","orderer":"주문자","orderer_review":"주문자{{separator}}리뷰","booking_review":"예약자 리뷰","customer":"예약자","customer_review":"예약자{{separator}}리뷰","book_and_order":"예약·주문","book_and_order_review":"예약·주문 리뷰","booking_and_qna":"예약 및 이용 안내","bookmark":"저장하기","route":"길찾기","share":"공유","address":"주소","qna":"문의","road_address":"도로명","old_address":"지번","clipboard":"복사","map":"지도","navigation":"내비게이션","roadview":"거리뷰","show_map":"지도보기","show_list":"목록보기","show_more":"더보기","services":"일반예약상품","review_photos":"예약자 사진","less":"접기","saved":"저장됨","save":"저장","transit":"대중교통","car":"자동차","walk":"도보","prev":"이전","next":"다음","booking_pickup":"포장예약","delivery":"배달","delivery_preparing":"배달준비중","delivery_closed":"배달종료","standard":"기본","call":"전화","details":"소개","unfold":"펼쳐보기","menu_table":"가격표","view_images":"이미지로 보기","free":"무료","page":"페이지","when":"기간","rates":"요금","host":"주최","prices":"가격비교","exhibitions":"전시","event_exhibitions":"전시·행사","event_festival":"축제·행사","visit":"방문","visitor":"방문자","visitor_review":"방문자{{separator}}리뷰","ticketer":"예매자","ticketer_review":"예매자{{separator}}리뷰","nPayPromotion":"N예약 혜택","nDeliveryPromotion":"N배달 혜택","waiting":"대기현황","michelin":"미쉐린 가이드","receipt":"영수증","recentlyBooked":"최근 {{text}}명 예약","krw":"{{text}}원","all_review":"전체 리뷰","by_latest":"최신순","by_rating":"평점순","highest_rated":"평점높은순","lowest_rated":"평점낮은순","set_search_location":"검색 위치 설정","centerBy_map":"현재 지도 중심","centerBy_my":"내 위치 중심","sortBy":"정렬 기준","sortBy_precision":"관련도순","sortBy_reviewCount":"리뷰순","sortBy_distance":"거리순","sortBy_price":"가격순","cancel":"취소","smartOrder":"스마트주문","gift":"선물하기","michelin_guide":"미쉐린 가이드 서울","chefs_commitments":"셰프와 레스토랑의 다짐","popular_menu":"인기메뉴"}}}};
#     (function (urls) {
#       var newUrls = urls;
#       if (!(newUrls && newUrls.length > 0)) return;
#       for (var i=0; i < newUrls.length; i++) {
#       nhn.common.load_js(newUrls[i],function(){},false);
#       }
#     })(['https://p-place.pstatic.net/assets/place/js/es2017.min.shim.0826.js','https://p-place.pstatic.net/assets/place/js/smoothscroll.shim.0529.js','https://p-place.pstatic.net/assets/place/js/nxplace.pc.nxPlacePcDistrict.1f081747e1909515a318.js?jsversion=new']);
#     nhn.common.load_js('https://ssl.pstatic.net/adimg3.search/adpost/js/ad.js',function(){},true);
#   </script>
# </div>
# <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_nreview_210114.css" rel="stylesheet" type="text/css"/> <section class="sc_new sp_nreview _prs_rvw _au_view_collection"> <div class="api_subject_bx"> <div class="api_title_area"> <h2 class="api_title">VIEW</h2> <div class="api_title_sub"> <div class="review_filter_area" role="listbox"> <a aria-selected="true" class="api_sub_option" href="?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;nso=&amp;where=view&amp;sm=tab_viw.all&amp;mode=normal" onclick="return goOtherCR(this, 'a=rvw.sourceall&amp;u='+urlencode(this.href));" role="option">전체</a> <a aria-selected="false" class="api_sub_option" href="?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;nso=&amp;where=blog&amp;sm=tab_viw.all" onclick="return goOtherCR(this, 'a=rvw.sourceblog&amp;u='+urlencode(this.href));" role="option">블로그</a> <a aria-selected="false" class="api_sub_option" href="?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;nso=&amp;where=article&amp;sm=tab_viw.all" onclick="return goOtherCR(this, 'a=rvw.sourcecafe&amp;u='+urlencode(this.href));" role="option">카페</a> </div><div aria-label="뷰타입 필터를 선택하세요" class="review_option_area" role="listbox"> <a aria-selected="true" class="item" href="?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;nso=&amp;where=view&amp;sm=tab_viw.all&amp;mode=normal" onclick="return goOtherCR(this, 'a=rvw.optiontext&amp;u='+urlencode(this.href));" role="option"><i class="spnew api_ico_view type_default">기본뷰</i></a> <a aria-selected="false" class="item" href="?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;nso=&amp;where=view&amp;sm=tab_viw.all&amp;mode=timeline" onclick="return goOtherCR(this, 'a=rvw.optionday&amp;u='+urlencode(this.href));" role="option"><i class="spnew api_ico_view type_timeline">타임라인뷰</i></a> <a aria-selected="false" class="item" href="?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;nso=&amp;where=view&amp;sm=tab_viw.all&amp;mode=image" onclick="return goOtherCR(this, 'a=rvw.optionimg&amp;u='+urlencode(this.href));" role="option"><i class="spnew api_ico_view type_media">멀티미디어뷰</i></a> </div></div></div><div class="_svp_list"> <tag-toggle data-selected-class="mod_bg"> <div class="api_pcpg_wrap _open_target" data-open-class="open"> <tab-list data-aria-attr="aria-pressed" data-index="tag" data-selected-class="mod_bg"> <div class="api_flicking_wrap api_group_tag _scroller"> <div class="flick_bx"> <a aria-pressed="true" class="tag mod_bg _tab" data-index="topic0" href="#" onclick=" tCR('a=rvw.topic&amp;i=90187dce_000000000000&amp;g=&amp;u=javascript'); return false;" ondragstart="return false" role="button"><span class="txt">전체</span></a> </div> <div class="flick_bx"> <a class="tag _tab" data-index="topic1" href="#" onclick=" tCR('a=rvw*i.topic&amp;i=90187dce_000000000000&amp;g=%EC%A0%9C%EC%A3%BC%ED%95%AD%EA%B3%B5&amp;u=javascript'); return false;" ondragstart="return false" role="button"><span class="txt">제주항공</span></a> </div> <div class="flick_bx"> <a class="tag _tab" data-index="topic2" href="#" onclick=" tCR('a=rvw*k.topic&amp;i=90187dce_000000000000&amp;g=%EB%A7%9B%EC%A7%91&amp;u=javascript'); return false;" ondragstart="return false" role="button"><span class="txt">맛집</span></a> </div> <div class="flick_bx"> <a class="tag _tab" data-index="topic3" href="#" onclick=" tCR('a=rvw*k.topic&amp;i=90187dce_000000000000&amp;g=%EC%B9%B4%ED%8E%98&amp;u=javascript'); return false;" ondragstart="return false" role="button"><span class="txt">카페</span></a> </div> <div class="flick_bx"> <a class="tag _tab" data-index="topic4" href="#" onclick=" tCR('a=rvw*i.topic&amp;i=90187dce_000000000000&amp;g=%EC%B9%B4%ED%8E%98%EA%B8%80&amp;u=javascript'); return false;" ondragstart="return false" role="button"><span class="txt">카페글</span></a> </div> <div class="flick_bx"> <a class="tag _tab" data-index="topic5" href="#" onclick=" tCR('a=rvw*k.topic&amp;i=90187dce_000000000000&amp;g=%EC%84%B1%EC%82%B0%EC%9D%BC%EC%B6%9C%EB%B4%89&amp;u=javascript'); return false;" ondragstart="return false" role="button"><span class="txt">성산일출봉</span></a> </div> <d ...
# <script> /* [AU] 인라인 스크립트 */ (function () { var CLASS_SECTION = "_sp_ntotal"; var CLASS_MARGIN = "type_margin"; var sectionEls = Array.prototype.slice.call(document.querySelectorAll("section." + CLASS_SECTION)); function matches(element, selector) { if (element.matches) return element.matches(selector); if (element.msMatchesSelector) return element.msMatchesSelector(selector); return false; } /* 연속되는 섹션 요소인지 검사한다. */ function isNextSiblingSection(sectionEl) { var targetEl = sectionEl; var targetTagName = targetEl.tagName.toLowerCase(); do { targetEl = targetEl.previousElementSibling; targetTagName = targetEl ? targetEl.tagName.toLowerCase() : ""; } while ( targetEl !== null && ( targetTagName === "script" || targetTagName === "link" ) ); if (targetEl === null) { return false; } return ( targetTagName === "section" && matches(targetEl, "." + CLASS_SECTION) ); } for (var i = 0; i < sectionEls.length; ++i) { if (isNextSiblingSection(sectionEls[i])) { sectionEls[i].classList.add(CLASS_MARGIN); } } })(); </script> <script type="text/javascript">
#     var _elAdIndLayerBz = null;
#     var _elAdIndLayerTimeBz;
#     var _elDscNcautionBz = null;
#
#     function adInfoShowBz(el) {
#       if (_elAdIndLayerBz) {
#         adInfoHideBz();
#         return false;
#       } else {
#         if (!_elDscNcautionBz) {
#           _elDscNcautionBz = $Element(el).parent();
#         }
#         _elDscNcautionBz._element.style.zIndex = 121;
#         _elAdIndLayerBz = $Element(el).next();
#         _elAdIndLayerBz.show();
#         _elAdIndLayerTimeBz = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHideBz() {
#       if (_elAdIndLayerBz) {
#         if (_elDscNcautionBz) {
#           _elDscNcautionBz._element.style.zIndex = 0;
#         }
#         _elAdIndLayerBz.hide();
#         _elAdIndLayerBz = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerBz(e) {
#       if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#   </script>
# <div class="ad_section section _bz_section bg_type_v2">
# <div class="section_head"><h2>비즈사이트</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">제주도</strong>
# <em class="dsc_ncaution_quotation">’</em>
# </span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowBz(this)) goOtherCR(this, 'a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
# <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ad_area nx_power" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=qgH92Mt2yYFO2H-JDuz3BgnHmiPw4LnwM_GTY9_-...">
# <ul class="lst_type ">
# <li class="lst" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=XakXqrb0hYohOriUgHWVVv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000120418713&amp;d=' + urlencode('http://www.auction.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">옥션 제주도</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=XakXqrb0hYohOriUgHWVVv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000120418713&amp;d='+urlencode('http://www.auction.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.auction.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               옥션 설맞이 쇼핑축제! 누구나 매일 최대 15%+스마일클럽은 20% 할인쿠폰증정!
#             </p></div>
# </div>
# </li>
# <li class="lst" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=VnNjZ556iWRFoGs5Tf7nX////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000121470387&amp;d=' + urlencode('https://www.lotteon.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주도,롯데ON</div>
# </a>
# <div class="url_area">
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.naverlogin&amp;r=2&amp;i=nad-a001-01-000000121470387&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <p>네이버 아이디로 로그인이 가능합니다.</p>
# <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=VnNjZ556iWRFoGs5Tf7nX////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000121470387&amp;d='+urlencode('https://www.lotteon.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.lotteon.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               선착순특가딜+11종쿠폰+5%적립 24시간 퍼스트먼데이 혜택챙기기
#             </p></div>
# </div>
# </li>
# <li class="lst" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=c0qNoxM4GbjjwAWCfzmEfv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000074426748&amp;d=' + urlencode('http://www.to-jeju.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주도 특가 티오제주</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=c0qNoxM4GbjjwAWCfzmEfv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000074426748&amp;d='+urlencode('http://www.to-jeju.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.to-jeju.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               조금더 알뜰한 <strong class="hl">제주도</strong>, 주중/휴일 항공/숙소/렌트카 최대 90% 할인!
#             </p></div>
# </div>
# </li>
# <li class="lst" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=eoZIJDqnk59GZdOSyE9oZv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000084429725&amp;d=' + urlencode('http://blog.naver.com/han4834') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주도 노형권 브리즈스테이</div>
# </a>
# <div class="url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=eoZIJDqnk59GZdOSyE9oZv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000084429725&amp;d='+urlencode('http://blog.naver.com/han4834')+'&amp;u='+urlencode(this.href));" target="_blank">blog.naver.com/han4834</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">제주도</strong> 노형권 명품빌라트 브리즈스테이 36평형 특별조건분양
#             </p></div>
# </div>
# </li>
# <li class="lst" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=R8vA643meJUjkK2ZUMIZP////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000120479927&amp;d=' + urlencode('https://smartstore.naver.com/nichirich') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">니치리치샵</div>
# </a>
# <div class="url_area">
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay_plus" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.checkout&amp;r=5&amp;i=nad-a001-01-000000120479927&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=R8vA643meJUjkK2ZUMIZP////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000120479927&amp;d='+urlencode('https://smartstore.naver.com/nichirich')+'&amp;u='+urlencode(this.href));" target="_blank">smartstore.naver.com/nichirich</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#
#               실제 쇼호스트와 인플루언서가 선택한 리얼후기 프리미엄 최저가 몰
#             </p></div>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;referenceId=htQ1mwprvxsssbnJ7DdssssssTl-030056" onclick="return goOtherCR(this, 'a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_ad"></i></a>
# </div>
# </div>
# </div>
# <script>g_crt+="&bt=26";</script>
# <div class="api_sc_page_wrap"> <div class="sc_page"> <a aria-disabled="true" class="btn_prev" role="button"><i class="spnew ico_page_arr">이전</i></a> <div class="sc_page_inner"> <a aria-pressed="true" class="btn" href="?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;sm=tab_pge&amp;where=nexearch" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=1&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">1</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=2&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=2&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">2</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=3&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=11&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=3&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">3</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=4&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=21&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=4&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">4</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=5&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=5&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">5</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=6&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=41&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=6&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">6</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=7&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=51&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=7&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">7</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=8&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=8&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">8</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=9&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=71&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=9&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">9</a> <a aria-pressed="false" class="btn" href="?display=10&amp;f=&amp;filetype=0&amp;page=10&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=81&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=10&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">10</a> </div> <a aria-disabled="false" class="btn_next" href="?display=10&amp;f=&amp;filetype=0&amp;page=11&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=11&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button"><i class="spnew ico_page_arr">다음</i></a> </div> </div> <section class="sc_new sp_nkeyword" id="nx_footer_related_keywords"> <div class="api_subject_bx _related_box"> <div class="api_title_area"> <h2 class="api_title">연관 검색어<a class="api_link_help" href="https://help.naver.com/support/alias/search/word/word_1.naver" onclick="return go ...

# %%
title = soup.find('a')
title
# Out:
# <a href="#lnb"><span>메뉴 영역으로 바로가기</span></a>

# %%
title.get_text()
# Out:
# '메뉴 영역으로 바로가기'

# %%
title = soup.find('a', class_="api_txt_lines total_tit")
title
# Out:
# <a class="api_txt_lines total_tit" href="https://blog.naver.com/jbm993/222218791602" onclick="return goOtherCR(this, 'a=rvw*w.link&amp;r=1&amp;i=90000003_0000000000000033BD45AAB2&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 독채펜션 제주 함덕해수욕장 감성 숙소</a>

# %%
title = soup.find_all('a', class_="api_txt_lines total_tit")
title
# Out:
# [<a class="api_txt_lines total_tit" href="https://blog.naver.com/jbm993/222218791602" onclick="return goOtherCR(this, 'a=rvw*w.link&amp;r=1&amp;i=90000003_0000000000000033BD45AAB2&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 독채펜션 제주 함덕해수욕장 감성 숙소</a>,
#  <a class="api_txt_lines total_tit" href="https://cafe.naver.com/hotellife/1610717" onclick="return goOtherCR(this, 'a=rvw*t.link&amp;r=2&amp;i=90000004_011EA92D001893DD00000000&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 여행기 식당편</a>,
#  <a class="api_txt_lines total_tit" href="https://blog.naver.com/nailstan/222202095179" onclick="return goOtherCR(this, 'a=rvw*f.link&amp;r=3&amp;i=90000003_0000000000000033BC46E64B&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 펜션 독채풀빌라로 추천해요</a>,
#  <a class="api_txt_lines total_tit" href="https://blog.naver.com/dptmfdl3135/222224883427" onclick="return goOtherCR(this, 'a=rvw*f.link&amp;r=4&amp;i=90000003_0000000000000033BDA29EE3&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 독채펜션 감성적인 신촌돌집</a>,
#  <a class="api_txt_lines total_tit" href="https://blog.naver.com/hp0210/222212291525" onclick="return goOtherCR(this, 'a=rvw*f.link&amp;r=5&amp;i=90000003_0000000000000033BCE27BC5&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark>펜션 귤밭뷰 숙소에서 향긋하게</a>,
#  <a class="api_txt_lines total_tit" href="https://blog.naver.com/anndam/222206454835" onclick="return goOtherCR(this, 'a=rvw*f.link&amp;r=6&amp;i=90000003_0000000000000033BC896C33&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 키즈펜션 풀빌라 더럭 아이 좋앙~</a>,
#  <a class="api_txt_lines total_tit" href="https://cafe.naver.com/jejutip/1890167" onclick="return goOtherCR(this, 'a=rvw*t.link&amp;r=7&amp;i=90000004_009F8C72001CD77700000000&amp;u='+urlencode(this.href))" target="_blank">첫 <mark>제주도</mark>여행 도와주세요 ㅠㅠ!</a>,
#  <a class="api_txt_lines total_tit" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30446592&amp;memberNo=8591454&amp;vType=VERTICAL" onclick="return goOtherCR(this, 'a=rvw*p.link&amp;r=8&amp;i=00055f7ca0_0001d09400&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 호텔 3곳, 따뜻한 겨울여행을 위한 애월 온수풀 호텔!</a>,
#  <a class="api_txt_lines total_tit" href="https://blog.naver.com/turpu/222220490444" onclick="return goOtherCR(this, 'a=rvw*f.link&amp;r=9&amp;i=90000003_0000000000000033BD5F96CC&amp;u='+urlencode(this.href))" target="_blank">국내 이색 여행지 <mark>제주도</mark> 금능석물원</a>]

# %%
all_title = []
for item in title:
    all_title.append(item.get_text())
all_title
# Out:
# ['제주도 독채펜션 제주 함덕해수욕장 감성 숙소',
#  '제주도 여행기 식당편',
#  '제주도 펜션 독채풀빌라로 추천해요',
#  '제주도 독채펜션 감성적인 신촌돌집',
#  '제주도펜션 귤밭뷰 숙소에서 향긋하게',
#  '제주도 키즈펜션 풀빌라 더럭 아이 좋앙~',
#  '첫 제주도여행 도와주세요 ㅠㅠ!',
#  '제주도 호텔 3곳, 따뜻한 겨울여행을 위한 애월 온수풀 호텔!',
#  '국내 이색 여행지 제주도 금능석물원']

# %% [markdown]
# ## Selenium 모듈
# =실제 사용자가 사용하는 것 처럼 작동하므로 BeautifulSoup으로 안되는 경우에도 대부분 적용 가능하다

# %%
'''
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
'''
# Out:
# '\nfrom selenium import webdriver\nfrom selenium.webdriver.common.keys import Keys\nimport time\n'

# %%
#path 변수에 자신의 chromedriver가 있는 파일 위치를 할당

#window : ~/chromedriver.exe
#mac : ~/chromedriver (.exe 빼기) 
path = 'C:/Users/USER/ybigta/세션/chromedriver.exe'

driver = webdriver.Chrome(path)

# %%
"""
#webdriver에 옵션 적용 가능
#options 정의
options = webdriver.ChromeOptions()

#브라우저 창이 안뜨고 실행
options.add_argument('headless')
#브라우저 사이즈 설정
options.add_argument('window-size=1920x1080')


#옵션 적용

driver = webdriver.Chrome(path, options=options)
"""
# Out:
# "\n#webdriver에 옵션 적용 가능\n#options 정의\noptions = webdriver.ChromeOptions()\n\n#브라우저 창이 안뜨고 실행\noptions.add_argument('headless')\n#브라우저 사이즈 설정\noptions.add_argument('window-size=1920x1080')\n\n\n#옵션 적용\n\ndriver = webdriver.Chrome(path, options=options)\n"

# %%
driver.get('https://www.naver.com/')

#검색창에 커서 두기
search = driver.find_element_by_id('query')
time.sleep(1)

#검색어 입력
search.send_keys('제주도')
time.sleep(1)
#Keys.RETURN = Enter 입력
search.send_keys(Keys.RETURN)
time.sleep(1)

#View목록
search = driver.find_element_by_link_text('이미지')
search.click()

# %%
driver.get('https://finance.naver.com/')

all_title=[]

for i in range(1,5):
    i=str(i)
    css = '#content > div.article > div.section > div.news_area > div > ul > li:nth-child(' + i + ') > span > a'
    content = driver.find_element_by_css_selector(css)
    all_title.append(content.text)

print(all_title)
# Out:
# ['[Asia마감] 저가 매수 유입에 일제히 상승…닛케이 1.55%↑', "[시황종합] 코스피, 2.7% 급등 3050선…외인·기관 '쌍끌이'", '[마켓뷰] 코스피 2% 넘게 상승해 3050선 돌파…"상승 여력 있다"', '[외환마감]코스피, 5거래일만에 오르자..환율, 1110원중반대로 하락']

# %%
#현재 열려있는 페이지 url 찾기
url = driver.current_url
url
# Out:
# 'https://comic.naver.com/webtoon/list.nhn?titleId=687915'
